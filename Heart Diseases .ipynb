# %%
import pandas as pd

# %%
df=pd.read_csv("heart_disease.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# age                int64
# sex                int64
# cp                 int64
# trestbps           int64
# chol               int64
# fbs                int64
# restecg            int64
# thalach            int64
# exang              int64
# oldpeak          float64
# slope              int64
# ca                 int64
# thal               int64
# smoking            int64
# diabetes           int64
# bmi              float64
# heart_disease      int64
# dtype: object

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
# ...

# %%
df.isnull().sum()
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
# ...

# %%
df1=df.dropna()
df1
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df1.reset_index()
# Out:
#       index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0         0   67    1   2       111   536    0        2       88      0
# 1         1   57    1   3       109   107    0        2      119      0
# 2         2   43    1   4       171   508    0        1      113      0
# 3         3   71    0   4        90   523    0        2      152      0
# 4         4   36    1   2       119   131    0        2      128      0
# ...     ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 3064   3064   52    0   1       169   479    0        0      124      0
# 3065   3065   75    0   4        90   372    0        2      141      0
# 3066   3066   68    1   4       166   564    0        1       76      0
# 3067   3067   66    0   3       143   113    1        1      207      0
# 3068   3068   38    1   4       100   507    0        1      187      0
#
#       oldpeak  slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df1.reset_index(drop=True)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df.fillna(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'smoking', 'diabetes', 'bmi',
#        'heart_disease'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age          sex           cp     trestbps         chol  \
# count  3069.00000  3069.000000  3069.000000  3069.000000  3069.000000
# mean     52.50114     0.555556     2.489736   145.306289   347.219941
# std      13.70752     0.496985     1.110417    31.602321   146.853319
# min      29.00000     0.000000     1.000000    90.000000   100.000000
# 25%      41.00000     0.000000     2.000000   118.000000   215.000000
# 50%      53.00000     1.000000     2.000000   146.000000   350.000000
# 75%      64.00000     1.000000     3.000000   172.000000   475.000000
# max      76.00000     1.000000     4.000000   200.000000   600.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  3069.000000  3069.000000  3069.000000  3069.000000  3069.000000
# mean      0.145650     1.004236   135.157380     0.176279     3.189052
# std       0.352813     0.812016    43.353197     0.381119     1.802815
# ...

# %%
df.describe().T
# Out:
#                 count        mean         std    min    25%    50%    75%  \
# age            3069.0   52.501140   13.707520   29.0   41.0   53.0   64.0
# sex            3069.0    0.555556    0.496985    0.0    0.0    1.0    1.0
# cp             3069.0    2.489736    1.110417    1.0    2.0    2.0    3.0
# trestbps       3069.0  145.306289   31.602321   90.0  118.0  146.0  172.0
# chol           3069.0  347.219941  146.853319  100.0  215.0  350.0  475.0
# fbs            3069.0    0.145650    0.352813    0.0    0.0    0.0    0.0
# restecg        3069.0    1.004236    0.812016    0.0    0.0    1.0    2.0
# thalach        3069.0  135.157380   43.353197   60.0   98.0  135.0  172.0
# exang          3069.0    0.176279    0.381119    0.0    0.0    0.0    0.0
# oldpeak        3069.0    3.189052    1.802815    0.0    1.6    3.2    4.7
# slope          3069.0    2.023786    0.817679    1.0    1.0    2.0    3.0
# ca             3069.0    0.626588    0.891447    0.0    0.0    0.0    1.0
# ...

# %%
df.describe().T.reset_index()
# Out:
#             index   count        mean         std    min    25%    50%    75%  \
# 0             age  3069.0   52.501140   13.707520   29.0   41.0   53.0   64.0
# 1             sex  3069.0    0.555556    0.496985    0.0    0.0    1.0    1.0
# 2              cp  3069.0    2.489736    1.110417    1.0    2.0    2.0    3.0
# 3        trestbps  3069.0  145.306289   31.602321   90.0  118.0  146.0  172.0
# 4            chol  3069.0  347.219941  146.853319  100.0  215.0  350.0  475.0
# 5             fbs  3069.0    0.145650    0.352813    0.0    0.0    0.0    0.0
# 6         restecg  3069.0    1.004236    0.812016    0.0    0.0    1.0    2.0
# 7         thalach  3069.0  135.157380   43.353197   60.0   98.0  135.0  172.0
# 8           exang  3069.0    0.176279    0.381119    0.0    0.0    0.0    0.0
# 9         oldpeak  3069.0    3.189052    1.802815    0.0    1.6    3.2    4.7
# 10          slope  3069.0    2.023786    0.817679    1.0    1.0    2.0    3.0
# ...

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#             index   count        mean         std    min    25%    50%    75%  \
# 0             age  3069.0   52.501140   13.707520   29.0   41.0   53.0   64.0
# 1             sex  3069.0    0.555556    0.496985    0.0    0.0    1.0    1.0
# 2              cp  3069.0    2.489736    1.110417    1.0    2.0    2.0    3.0
# 3        trestbps  3069.0  145.306289   31.602321   90.0  118.0  146.0  172.0
# 4            chol  3069.0  347.219941  146.853319  100.0  215.0  350.0  475.0
# 5             fbs  3069.0    0.145650    0.352813    0.0    0.0    0.0    0.0
# 6         restecg  3069.0    1.004236    0.812016    0.0    0.0    1.0    2.0
# 7         thalach  3069.0  135.157380   43.353197   60.0   98.0  135.0  172.0
# 8           exang  3069.0    0.176279    0.381119    0.0    0.0    0.0    0.0
# 9         oldpeak  3069.0    3.189052    1.802815    0.0    1.6    3.2    4.7
# 10          slope  3069.0    2.023786    0.817679    1.0    1.0    2.0    3.0
# ...

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#             index   count        mean         std    min    25%    50%    75%  \
# 0             age  3069.0   52.501140   13.707520   29.0   41.0   53.0   64.0
# 1             sex  3069.0    0.555556    0.496985    0.0    0.0    1.0    1.0
# 2              cp  3069.0    2.489736    1.110417    1.0    2.0    2.0    3.0
# 3        trestbps  3069.0  145.306289   31.602321   90.0  118.0  146.0  172.0
# 4            chol  3069.0  347.219941  146.853319  100.0  215.0  350.0  475.0
# 5             fbs  3069.0    0.145650    0.352813    0.0    0.0    0.0    0.0
# 6         restecg  3069.0    1.004236    0.812016    0.0    0.0    1.0    2.0
# 7         thalach  3069.0  135.157380   43.353197   60.0   98.0  135.0  172.0
# 8           exang  3069.0    0.176279    0.381119    0.0    0.0    0.0    0.0
# 9         oldpeak  3069.0    3.189052    1.802815    0.0    1.6    3.2    4.7
# 10          slope  3069.0    2.023786    0.817679    1.0    1.0    2.0    3.0
# ...

# %%
Summary["varience"]=Summary["std"]**2Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                   0         1          2           3             4   \
# index            age       sex         cp    trestbps          chol
# count         3069.0    3069.0     3069.0      3069.0        3069.0
# mean        52.50114  0.555556   2.489736  145.306289    347.219941
# std         13.70752  0.496985   1.110417   31.602321    146.853319
# min             29.0       0.0        1.0        90.0         100.0
# 25%             41.0       0.0        2.0       118.0         215.0
# 50%             53.0       1.0        2.0       146.0         350.0
# 75%             64.0       1.0        3.0       172.0         475.0
# max             76.0       1.0        4.0       200.0         600.0
# IQR             23.0       1.0        1.0        54.0         260.0
# IW               6.5      -1.5        0.5        37.0        -175.0
# UW              98.5       2.5        4.5       253.0         865.0
# SkEW        3.669836  1.490126   3.314582    3.465723      1.749354
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# dtype: int64

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("heart_disease.csv")

# %%
sns.scatterplot(x=df['oldpeak'])
# Out:
# <AxesSubplot:xlabel='oldpeak'>

# %%
sns.scatterplot(df['restecg'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='restecg'>

# %%
sns.countplot(df['trestbps'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='trestbps', ylabel='count'>

# %%
sns.stripplot(x=df['trestbps'], y=df['diabetes'], jitter=True)
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='diabetes'>

# %%
df.groupby("sex")["heart_disease"].mean().plot(kind="bar")
plt.title("Heart Disease Rate by Sex")
plt.xlabel("Sex (0 = Female, 1 = Male)")
plt.ylabel("Rate of Heart Disease")
plt.show()

# %%
plt.plot(df["age"], df["chol"])
plt.title("Age vs Cholesterol")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.show()

# %%
df = pd.DataFrame({
    "age": np.random.randint(20, 70, 100),
    "chol": np.random.randint(150, 300, 100),
    "sex": np.random.choice([0, 1], 100),
    "heart_disease": np.random.choice([0, 1], 100)
})

# %%
df["sex"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["sex"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df.groupby("sex")["heart_disease"].sum().plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
plt.plot(df["age"], df["chol"])

# %%
plt.step(df["age"], df["chol"])

# %%
df[["age","chol"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["age"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="sex", y="chol", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
sns.violinplot(x="sex", y="chol", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
sns.kdeplot(df["age"], shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.rugplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
plt.scatter(df["age"], df["chol"])

# %%
plt.scatter(df["age"], df["chol"], s=df["sex"]*100)

# %%
plt.hexbin(df["age"], df["chol"], gridsize=20)

# %%
plt.plot(df["age"], df["chol"], marker="o")

# %%
df["heart_disease"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='heart_disease'>

# %%
df["heart_disease"].value_counts().plot.pie(labels=["No","Yes"])
# Out:
# <AxesSubplot:ylabel='heart_disease'>

# %%
df[["age","chol"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>

# %%
 #Make fake date column
df["date"] = pd.date_range("2024-01-01", periods=len(df))
df.plot(x="date", y="chol")                          # Time Series Line Chart
df.plot(x="date", y="chol", kind="bar")              # Time Series Bar Chart
df[["date","age","chol"]].set_index("date").plot.area()  # Stacked Area over Time
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[["age","chol","heart_disease"]])    # Pair Plot

# %%
labels=np.array(["A","B","C","D","E"]); values=[5,3,4,2,6]

# %%
plt.polar(np.linspace(0,2*np.pi,len(labels),endpoint=False), values)
