# %%
import pandas as pd

# %%
df=pd.read_csv("SpaceX Launches.csv")

# %%
df
# Out:
#     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# 216                 Starlink Group 2-8 (52 satellites)
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Flight No.             object
# Date and Time (UTC)    object
# Payload                object
# Payload Mass           object
# Orbit                  object
# Customer               object
# Launch Outcome         object
# Booster Landing        object
# Launch Sites           object
# Versions, Boosters     object
# dtype: object

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# ...

# %%
df.isnull().sum()
# Out:
# Flight No.             0
# Date and Time (UTC)    0
# Payload                0
# Payload Mass           0
# Orbit                  0
# Customer               0
# Launch Outcome         0
# Booster Landing        0
# Launch Sites           0
# Versions, Boosters     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop(5)
# Out:
#     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# 216                 Starlink Group 2-8 (52 satellites)
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# ...

# %%
df1=df.dropna()
df1
# Out:
#     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# 216                 Starlink Group 2-8 (52 satellites)
# ...

# %%
df1.reset_index()
# Out:
#      index Flight No.       Date and Time (UTC)  \
# 0        0          1         4 June 2010,18:45
# 1        1          2  8 December 2010,15:43[8]
# 2        2          3     22 May 2012,07:44[13]
# 3        3          4  8 October 2012,00:35[17]
# 4        4          5        1 March 2013,15:10
# ..     ...        ...                       ...
# 216    216        211  17 March 2023,19:26[506]
# 217    217        212  17 March 2023,23:38[506]
# 218    218        213  24 March 2023,15:43[509]
# 219    219        214   29 March 202320:01[512]
# 220    220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ...

# %%
df1.reset_index(drop=True)
# Out:
#     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# 216                 Starlink Group 2-8 (52 satellites)
# ...

# %%
df.fillna(5)
# Out:
#     Flight No.       Date and Time (UTC)  \
# 0            1         4 June 2010,18:45
# 1            2  8 December 2010,15:43[8]
# 2            3     22 May 2012,07:44[13]
# 3            4  8 October 2012,00:35[17]
# 4            5        1 March 2013,15:10
# ..         ...                       ...
# 216        211  17 March 2023,19:26[506]
# 217        212  17 March 2023,23:38[506]
# 218        213  24 March 2023,15:43[509]
# 219        214   29 March 202320:01[512]
# 220        215    2 April 202314:29[513]
#
#                                                Payload  \
# 0                 Dragon Spacecraft Qualification Unit
# 1               SpaceX COTS Demo Flight 1(Dragon C101)
# 2           SpaceX COTS Demo Flight 2[14](Dragon C102)
# 3                        SpaceX CRS-1[18](Dragon C103)
# 4                        SpaceX CRS-2[18](Dragon C104)
# ..                                                 ...
# 216                 Starlink Group 2-8 (52 satellites)
# ...

# %%
df.columns
# Out:
# Index(['Flight No.', 'Date and Time (UTC)', 'Payload', 'Payload Mass', 'Orbit',
#        'Customer', 'Launch Outcome', 'Booster Landing', 'Launch Sites',
#        'Versions, Boosters'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Flight No. Date and Time (UTC)                               Payload  \
# count         221                 221                                   221
# unique        221                 221                                   221
# top             1   4 June 2010,18:45  Dragon Spacecraft Qualification Unit
# freq            1                   1                                     1
#
#                  Payload Mass Orbit Customer Launch Outcome  \
# count                     221   221      221            221
# unique                    156    20       75             39
# top     15,600 kg (34,400 lb)   LEO   SpaceX        Success
# freq                       15    90       72            183
#
#             Booster Landing  Launch Sites Versions, Boosters
# count                   221           221                221
# unique                   48            10                218
# top     Success(drone ship)  CCSFS,SLC-40            F9 v1.1
# ...

# %%
df.describe().T
# Out:
#                     count unique                                   top freq
# Flight No.            221    221                                     1    1
# Date and Time (UTC)   221    221                     4 June 2010,18:45    1
# Payload               221    221  Dragon Spacecraft Qualification Unit    1
# Payload Mass          221    156                 15,600 kg (34,400 lb)   15
# Orbit                 221     20                                   LEO   90
# Customer              221     75                                SpaceX   72
# Launch Outcome        221     39                               Success  183
# Booster Landing       221     48                   Success(drone ship)  129
# Launch Sites          221     10                          CCSFS,SLC-40   71
# Versions, Boosters    221    218                               F9 v1.1    4

# %%
df.describe().T.reset_index()
# Out:
#                  index count unique                                   top freq
# 0           Flight No.   221    221                                     1    1
# 1  Date and Time (UTC)   221    221                     4 June 2010,18:45    1
# 2              Payload   221    221  Dragon Spacecraft Qualification Unit    1
# 3         Payload Mass   221    156                 15,600 kg (34,400 lb)   15
# 4                Orbit   221     20                                   LEO   90
# 5             Customer   221     75                                SpaceX   72
# 6       Launch Outcome   221     39                               Success  183
# 7      Booster Landing   221     48                   Success(drone ship)  129
# 8         Launch Sites   221     10                          CCSFS,SLC-40   71
# 9   Versions, Boosters   221    218                               F9 v1.1    4

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# Series([], Name: null_values, dtype: float64)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# Series([], Name: null_value, dtype: float64)

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, unique, top, freq, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(x=df['Date and Time (UTC)'])
# Out:
# <AxesSubplot:xlabel='Date and Time (UTC)'>

# %%
sns.scatterplot(df['Payload'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Payload'>

# %%
sns.countplot(df['Payload'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Payload', ylabel='count'>

# %%
sns.stripplot(x=df['Date and Time (UTC)'], y=df['Payload'], jitter=True)
# Out:
# <AxesSubplot:xlabel='Date and Time (UTC)', ylabel='Payload'>

# %%
plt.plot(df["Date and Time (UTC)"], df["Payload"])
plt.title("T20 ")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Payload")
plt.show()

# %%
df["Date and Time (UTC)"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Payload"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["Date and Time (UTC)"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
plt.plot(df["Date and Time (UTC)"], df["Payload"])

# %%
df[["Orbit","Payload"]].plot.area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 df[["Orbit","Payload"]].plot.area()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1529, in PlotAccessor.area(self, x, y, **kwargs)
#    1458 def area(self, x=None, y=None, **kwargs):
#    1459     """
#    1460     Draw a stacked area plot.
#    1461
#    (...)
#    1527         >>> ax = df.plot.area(x='day')
#    1528     """
# -> 1529     return self(kind="area", x=x, y=y, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
df["Orbit"].plot(kind="hist", bins=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 df["Orbit"].plot(kind="hist", bins=10)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:327, in MPLPlot.generate(self)
# ...

# %%
sns.boxplot(x="Payload", y="Date and Time (UTC)", data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 sns.boxplot(x="Payload", y="Date and Time (UTC)", data=df)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2243, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
# ...

# %%
sns.violinplot(x="Date and Time (UTC)", y="Payload", data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 sns.violinplot(x="Date and Time (UTC)", y="Payload", data=df)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.kdeplot(df["Payload"], shade=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 sns.kdeplot(df["Payload"], shade=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.rugplot(df["Payload"])
# Out:
# <AxesSubplot:xlabel='Payload'>

# %%
plt.scatter(df["Date and Time (UTC)	"], df["Payload"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date and Time (UTC)\t'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.scatter(df["Date and Time (UTC)"], df["Payload"], s=df["Date and Time (UTC)"]*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 plt.scatter(df["Date and Time (UTC)"], df["Payload"], s=df["Date and Time (UTC)"]*100)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
df["Payload"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Payload'>

# %%
df[["Payload","Date and Time (UTC)"]].plot.area(stacked=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 df[["Payload","Date and Time (UTC)"]].plot.area(stacked=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1529, in PlotAccessor.area(self, x, y, **kwargs)
#    1458 def area(self, x=None, y=None, **kwargs):
#    1459     """
#    1460     Draw a stacked area plot.
#    1461
#    (...)
#    1527         >>> ax = df.plot.area(x='day')
#    1528     """
# -> 1529     return self(kind="area", x=x, y=y, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
labels=np.array(["A","B","C","D","E"]); values=[5,3,4,2,6]
