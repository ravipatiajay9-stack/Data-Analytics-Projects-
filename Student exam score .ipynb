# %%
import pandas as pd

# %%
df = pd.read_csv("Student_exam_scores.csv")

# %%
df
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# ...

# %%
df.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# ...

# %%
df1=df.dropna()
df1
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
df1.reset_index()
# Out:
#      index student_id  hours_studied  sleep_hours  attendance_percent  \
# 0        0       S001            8.0          8.8                72.1
# 1        1       S002            1.3          8.6                60.7
# 2        2       S003            4.0          8.2                73.7
# 3        3       S004            3.5          4.8                95.1
# 4        4       S005            9.1          6.4                89.8
# ..     ...        ...            ...          ...                 ...
# 195    195       S196           10.5          5.4                94.0
# 196    196       S197            7.1          6.1                85.1
# 197    197       S198            1.6          6.9                63.8
# 198    198       S199           12.0          7.3                50.5
# 199    199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# ...

# %%
df1.reset_index(drop=True)
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
df.fillna(5)
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'hours_studied', 'sleep_hours', 'attendance_percent',
#        'previous_scores', 'exam_score'],
#       dtype='object')

# %%
df.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count     200.000000   200.000000          200.000000       200.000000
# mean        6.325500     6.622000           74.830000        66.800000
# std         3.227317     1.497138           14.249905        15.663869
# min         1.000000     4.000000           50.300000        40.000000
# 25%         3.500000     5.300000           62.200000        54.000000
# 50%         6.150000     6.700000           75.250000        67.500000
# 75%         9.000000     8.025000           87.425000        80.000000
# max        12.000000     9.000000          100.000000        95.000000
#
#        exam_score
# count  200.000000
# mean    33.955000
# std      6.789548
# min     17.100000
# 25%     29.500000
# 50%     34.050000
# 75%     38.750000
# max     51.300000

# %%
df.describe().T
# Out:
#                     count     mean        std   min   25%    50%     75%  \
# hours_studied       200.0   6.3255   3.227317   1.0   3.5   6.15   9.000
# sleep_hours         200.0   6.6220   1.497138   4.0   5.3   6.70   8.025
# attendance_percent  200.0  74.8300  14.249905  50.3  62.2  75.25  87.425
# previous_scores     200.0  66.8000  15.663869  40.0  54.0  67.50  80.000
# exam_score          200.0  33.9550   6.789548  17.1  29.5  34.05  38.750
#
#                       max
# hours_studied        12.0
# sleep_hours           9.0
# attendance_percent  100.0
# previous_scores      95.0
# exam_score           51.3

# %%
df.describe().T.reset_index()
# Out:
#                 index  count     mean        std   min   25%    50%     75%  \
# 0       hours_studied  200.0   6.3255   3.227317   1.0   3.5   6.15   9.000
# 1         sleep_hours  200.0   6.6220   1.497138   4.0   5.3   6.70   8.025
# 2  attendance_percent  200.0  74.8300  14.249905  50.3  62.2  75.25  87.425
# 3     previous_scores  200.0  66.8000  15.663869  40.0  54.0  67.50  80.000
# 4          exam_score  200.0  33.9550   6.789548  17.1  29.5  34.05  38.750
#
#      max
# 0   12.0
# 1    9.0
# 2  100.0
# 3   95.0
# 4   51.3

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#                 index  count     mean        std   min   25%    50%     75%  \
# 0       hours_studied  200.0   6.3255   3.227317   1.0   3.5   6.15   9.000
# 1         sleep_hours  200.0   6.6220   1.497138   4.0   5.3   6.70   8.025
# 2  attendance_percent  200.0  74.8300  14.249905  50.3  62.2  75.25  87.425
# 3     previous_scores  200.0  66.8000  15.663869  40.0  54.0  67.50  80.000
# 4          exam_score  200.0  33.9550   6.789548  17.1  29.5  34.05  38.750
#
#      max     IQR
# 0   12.0   5.500
# 1    9.0   2.725
# 2  100.0  25.225
# 3   95.0  26.000
# 4   51.3   9.250

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
SummarySummary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 7>()
#       5 Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
#       6 Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
# ----> 7 SummarySummary["varience"]=Summary["std"]**2
#       8 Summary["Range"]=Summary[max]-Summary[min]
#      10 Summary.T
#
# NameError: name 'SummarySummary' is not defined

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(x=df['hours_studied'])
# Out:
# <AxesSubplot:xlabel='hours_studied'>

# %%
sns.scatterplot(df['sleep_hours'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sleep_hours'>

# %%
sns.countplot(df['hours_studied'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hours_studied', ylabel='count'>

# %%
plt.plot(df["hours_studied"], df["sleep_hours"])
plt.title("sleep_hours")
plt.xlabel("hours_studied")
plt.ylabel("sleep_hours")
plt.show()

# %%
df["hours_studied"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["sleep_hours"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["hours_studied"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
plt.plot(df["sleep_hours"], df["hours_studied"])

# %%
df[["hours_studied","sleep_hours"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["hours_studied"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="hours_studied", y="sleep_hours", data=df)
# Out:
# <AxesSubplot:xlabel='hours_studied', ylabel='sleep_hours'>

# %%
sns.violinplot(x="hours_studied", y="sleep_hours", data=df)
# Out:
# <AxesSubplot:xlabel='hours_studied', ylabel='sleep_hours'>

# %%
sns.kdeplot(df["hours_studied"], shade=True)
# Out:
# <AxesSubplot:xlabel='hours_studied', ylabel='Density'>

# %%
sns.rugplot(df["sleep_hours"])
# Out:
# <AxesSubplot:xlabel='sleep_hours'>

# %%
plt.scatter(df["hours_studied"], df["sleep_hours"])

# %%
df["hours_studied"].value_counts().plot(kind="pie", autopct="%1.1f%%")

# %%
df[["hours_studied","sleep_hours"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>
