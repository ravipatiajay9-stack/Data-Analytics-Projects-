# %%
import pandas as pd

# %%
df=pd.read_csv("covid.csv")

# %%
df
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Patient_ID                   int64
# Age                          int64
# Gender                      object
# Region                      object
# Preexisting_Condition       object
# Date_of_Infection           object
# COVID_Strain                object
# Symptoms                    object
# Severity                    object
# Hospitalized                object
# Hospital_Admission_Date     object
# Hospital_Discharge_Date     object
# ICU_Admission               object
# Ventilator_Support          object
# Recovered                   object
# Date_of_Recovery            object
# Reinfection                 object
# Date_of_Reinfection         object
# Vaccination_Status          object
# Vaccine_Type                object
# Doses_Received               int64
# Date_of_Last_Dose           object
# Long_COVID_Symptoms         object
# Occupation                  object
# Smoking_Status              object
# BMI                        float64
# dtype: object

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID                    0
# Age                           0
# Gender                        0
# Region                        0
# Preexisting_Condition         0
# Date_of_Infection             0
# COVID_Strain                  0
# Symptoms                      0
# Severity                      0
# Hospitalized                  0
# Hospital_Admission_Date    2124
# Hospital_Discharge_Date    2124
# ICU_Admission                 0
# Ventilator_Support            0
# Recovered                     0
# Date_of_Recovery           1492
# Reinfection                   0
# Date_of_Reinfection        2715
# Vaccination_Status            0
# Vaccine_Type                  0
# Doses_Received                0
# Date_of_Last_Dose          1528
# Long_COVID_Symptoms           0
# Occupation                    0
# Smoking_Status                0
# BMI                           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 9983

# %%
df.drop(5)
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df1=df.dropna()
df1
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 98            99   66  Female   Syddanmark                  None
# 230          231   68    Male  Midtjylland                  None
# 316          317   48  Female  Nordjylland          Hypertension
# 389          390   39    Male   Syddanmark                  None
# 421          422   34  Female     Sjælland        Cardiovascular
# 643          644   49    Male     Sjælland        Cardiovascular
# 761          762   18  Female     Sjælland               Obesity
# 902          903   72    Male     Sjælland               Obesity
# 1267        1268   18    Male     Sjælland              Diabetes
# 1444        1445   68  Female  Hovedstaden          Hypertension
# 1657        1658   22    Male  Hovedstaden              Diabetes
# 1974        1975   52  Female   Syddanmark                Asthma
# 2138        2139   70  Female  Hovedstaden        Cardiovascular
# ...

# %%
df1.reset_index()
# Out:
#     index  Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0      98          99   66  Female   Syddanmark                  None
# 1     230         231   68    Male  Midtjylland                  None
# 2     316         317   48  Female  Nordjylland          Hypertension
# 3     389         390   39    Male   Syddanmark                  None
# 4     421         422   34  Female     Sjælland        Cardiovascular
# 5     643         644   49    Male     Sjælland        Cardiovascular
# 6     761         762   18  Female     Sjælland               Obesity
# 7     902         903   72    Male     Sjælland               Obesity
# 8    1267        1268   18    Male     Sjælland              Diabetes
# 9    1444        1445   68  Female  Hovedstaden          Hypertension
# 10   1657        1658   22    Male  Hovedstaden              Diabetes
# 11   1974        1975   52  Female   Syddanmark                Asthma
# ...

# %%
df1.reset_index(drop=True)
# Out:
#     Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0           99   66  Female   Syddanmark                  None
# 1          231   68    Male  Midtjylland                  None
# 2          317   48  Female  Nordjylland          Hypertension
# 3          390   39    Male   Syddanmark                  None
# 4          422   34  Female     Sjælland        Cardiovascular
# 5          644   49    Male     Sjælland        Cardiovascular
# 6          762   18  Female     Sjælland               Obesity
# 7          903   72    Male     Sjælland               Obesity
# 8         1268   18    Male     Sjælland              Diabetes
# 9         1445   68  Female  Hovedstaden          Hypertension
# 10        1658   22    Male  Hovedstaden              Diabetes
# 11        1975   52  Female   Syddanmark                Asthma
# 12        2139   70  Female  Hovedstaden        Cardiovascular
# 13        2332   76  Female  Hovedstaden               Obesity
# ...

# %%
df.fillna(5)
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Region', 'Preexisting_Condition',
#        'Date_of_Infection', 'COVID_Strain', 'Symptoms', 'Severity',
#        'Hospitalized', 'Hospital_Admission_Date', 'Hospital_Discharge_Date',
#        'ICU_Admission', 'Ventilator_Support', 'Recovered', 'Date_of_Recovery',
#        'Reinfection', 'Date_of_Reinfection', 'Vaccination_Status',
#        'Vaccine_Type', 'Doses_Received', 'Date_of_Last_Dose',
#        'Long_COVID_Symptoms', 'Occupation', 'Smoking_Status', 'BMI'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Patient_ID          Age  Doses_Received          BMI
# count  3000.000000  3000.000000     3000.000000  3000.000000
# mean   1500.500000    53.944000        0.981667    25.096500
# std     866.169729    20.872919        1.154025     4.898435
# min       1.000000    18.000000        0.000000    10.200000
# 25%     750.750000    36.000000        0.000000    21.800000
# 50%    1500.500000    54.000000        0.000000    25.100000
# 75%    2250.250000    72.000000        2.000000    28.500000
# max    3000.000000    89.000000        3.000000    44.600000

# %%
df.describe().T
# Out:
#                  count         mean         std   min     25%     50%  \
# Patient_ID      3000.0  1500.500000  866.169729   1.0  750.75  1500.5
# Age             3000.0    53.944000   20.872919  18.0   36.00    54.0
# Doses_Received  3000.0     0.981667    1.154025   0.0    0.00     0.0
# BMI             3000.0    25.096500    4.898435  10.2   21.80    25.1
#
#                     75%     max
# Patient_ID      2250.25  3000.0
# Age               72.00    89.0
# Doses_Received     2.00     3.0
# BMI               28.50    44.6

# %%
df.describe().T.reset_index()
# Out:
#             index   count         mean         std   min     25%     50%  \
# 0      Patient_ID  3000.0  1500.500000  866.169729   1.0  750.75  1500.5
# 1             Age  3000.0    53.944000   20.872919  18.0   36.00    54.0
# 2  Doses_Received  3000.0     0.981667    1.154025   0.0    0.00     0.0
# 3             BMI  3000.0    25.096500    4.898435  10.2   21.80    25.1
#
#        75%     max
# 0  2250.25  3000.0
# 1    72.00    89.0
# 2     2.00     3.0
# 3    28.50    44.6

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#             index   count         mean         std   min     25%     50%  \
# 0      Patient_ID  3000.0  1500.500000  866.169729   1.0  750.75  1500.5
# 1             Age  3000.0    53.944000   20.872919  18.0   36.00    54.0
# 2  Doses_Received  3000.0     0.981667    1.154025   0.0    0.00     0.0
# 3             BMI  3000.0    25.096500    4.898435  10.2   21.80    25.1
#
#        75%     max     IQR
# 0  2250.25  3000.0  1499.5
# 1    72.00    89.0    36.0
# 2     2.00     3.0     2.0
# 3    28.50    44.6     6.7

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#             index   count         mean         std   min     25%     50%  \
# 0      Patient_ID  3000.0  1500.500000  866.169729   1.0  750.75  1500.5
# 1             Age  3000.0    53.944000   20.872919  18.0   36.00    54.0
# 2  Doses_Received  3000.0     0.981667    1.154025   0.0    0.00     0.0
# 3             BMI  3000.0    25.096500    4.898435  10.2   21.80    25.1
#
#        75%     max     IQR       IW       UW      SkEW  kurtosis
# 0  2250.25  3000.0  1499.5 -1498.50  4499.50  1.218734  0.558433
# 1    72.00    89.0    36.0   -18.00   126.00  0.635678 -2.351209
# 2     2.00     3.0     2.0    -3.00     5.00  0.794056 -1.606626
# 3    28.50    44.6     6.7    11.75    38.55  1.446042  1.681086

# %%
Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                    0           1               2          3
# index     Patient_ID         Age  Doses_Received        BMI
# count         3000.0      3000.0          3000.0     3000.0
# mean          1500.5      53.944        0.981667    25.0965
# std       866.169729   20.872919        1.154025   4.898435
# min              1.0        18.0             0.0       10.2
# 25%           750.75        36.0             0.0       21.8
# 50%           1500.5        54.0             0.0       25.1
# 75%          2250.25        72.0             2.0       28.5
# max           3000.0        89.0             3.0       44.6
# IQR           1499.5        36.0             2.0        6.7
# IW           -1498.5       -18.0            -3.0      11.75
# UW            4499.5       126.0             5.0      38.55
# SkEW        1.218734    0.635678        0.794056   1.446042
# kurtosis    0.558433   -2.351209       -1.606626   1.681086
# varience    750250.0  435.678757        1.331774  23.994669
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Doses_Received    0
# BMI               0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Doses_Received    0
# BMI               0
# dtype: int64

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# Patient_ID        0
# Age               0
# Doses_Received    0
# BMI               0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Doses_Received    0
# BMI               0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# Patient_ID        0
# Age               0
# Doses_Received    0
# BMI               0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("covid.csv")

# %%
df
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %%
sns.scatterplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.scatterplot(df['Region'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region'>

# %%
sns.countplot(df['Region'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.stripplot(x=df['Region'], y=df['Age'], jitter=True)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Age'>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 df.groupby("covid")[""].mean().plot(kind="bar")
#       2 plt.title("Covid cases by Age Region")
#       3 plt.xlabel("Sex (0 = Female, 1 = Male)")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
# ...

# %%
plt.plot(df["Age"], df["Region"])
plt.title("Age vs Cholesterol")
plt.xlabel("Age")
plt.ylabel("Covid")
plt.show()

# %%
df["Age"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Region"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["Region"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
plt.plot(df["Age"], df["Region"])

# %%
plt.plot(df["Age"], df["Region"])

# %%
df[["Age","Region"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["Age"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="Region", y="Age", data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Age'>

# %%
sns.violinplot(x="Age", y="Region", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Region'>

# %%
sns.kdeplot(df["Age"], shade=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.rugplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
plt.scatter(df["Age"], df["Region"])

# %%
plt.scatter(df["Age"], df["Region"], s=df["Age"]*100)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.hexbin(df["Age"], df["Region"], gridsize=20, cmap='Blues')
plt.colorbar(label='Counts')
plt.xlabel("Age")
plt.ylabel("Region")
plt.title("Hexbin Plot of Age vs. Region")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 4>()
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(8, 6))
# ----> 4 plt.hexbin(df["Age"], df["Region"], gridsize=20, cmap='Blues')
#       5 plt.colorbar(label='Counts')
#       6 plt.xlabel("Age")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2572, in hexbin(x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, data, **kwargs)
#    2565 @_copy_docstring_and_deprecators(Axes.hexbin)
#    2566 def hexbin(
#    2567         x, y, C=None, gridsize=100, bins=None, xscale='linear',
#    (...)
#    2570         reduce_C_function=np.mean, mincnt=None, marginals=False, *,
#    2571         data=None, **kwargs):
# -> 2572     __ret = gca().hexbin(
# ...

# %%
plt.plot(df["Age"], df["Region"], marker="o")

# %%
df["Age"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'covid'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[["Age","Region"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>

# %%
 #Make fake date column
df["date"] = pd.date_range("2024-01-01", periods=len(df))
df.plot(x="date", y="chol")                          # Time Series Line Chart
df.plot(x="date", y="chol", kind="bar")              # Time Series Bar Chart
df[["date","age","chol"]].set_index("date").plot.area()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chol'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 sns.heatmap(df.Age(), annot=True)
#
# TypeError: 'Series' object is not callable

# %%
sns.pairplot(df[["Age", "Region"]]
plt.show() # Pair Plot
# Out:
#   Input In [81]
#     plt.show() # Pair Plot
#     ^
# SyntaxError: invalid syntax

# %%
labels=np.array(["A","B","C","D","E"]); values=[5,3,4,2,6]

# %%
labels=np.array(["A","B","C","D","E"]); values=[5,3,4,2,6]
