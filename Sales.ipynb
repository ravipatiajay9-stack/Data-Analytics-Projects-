# %%
import pandas as pd

# %%
df = pd.read_csv("hp_sales.csv", encoding_errors='ignore')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.info type(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df.infotype(df)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'infotype'

# %%
df.dtypes

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5157

# %%
df.drop(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df1=df.dropna()
df1
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df1.reset_index()
# Out:
#      index  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0       10        10223               37     100.00                1  3965.66
# 1       21        10361               20      72.55               13  1451.00
# 2       40        10270               21     100.00                9  4905.39
# 3       47        10347               30     100.00                1  3944.70
# 4       51        10391               24     100.00                4  2416.56
# ..     ...          ...              ...        ...              ...      ...
# 142   2667        10120               43      76.00               14  3268.00
# 143   2673        10223               26      67.20               15  1747.20
# 144   2685        10361               44     100.00               10  5001.92
# 145   2764        10361               35     100.00               11  4277.35
# 146   2791        10361               23      95.20               12  2189.60
#
# ...

# %%
df1.reset_index(drop=True)
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10223               37     100.00                1  3965.66
# 1          10361               20      72.55               13  1451.00
# 2          10270               21     100.00                9  4905.39
# 3          10347               30     100.00                1  3944.70
# 4          10391               24     100.00                4  2416.56
# ..           ...              ...        ...              ...      ...
# 142        10120               43      76.00               14  3268.00
# 143        10223               26      67.20               15  1747.20
# 144        10361               44     100.00               10  5001.92
# 145        10361               35     100.00               11  4277.35
# 146        10361               23      95.20               12  2189.60
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.fillna(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std       min       25%  \
# ORDERNUMBER      2823.0  10258.725115    92.085478  10100.00  10180.00
# QUANTITYORDERED  2823.0     35.092809     9.741443      6.00     27.00
# PRICEEACH        2823.0     83.658544    20.174277     26.88     68.86
# ORDERLINENUMBER  2823.0      6.466171     4.225841      1.00      3.00
# SALES            2823.0   3553.889072  1841.865106    482.13   2203.43
# QTR_ID           2823.0      2.717676     1.203878      1.00      2.00
# MONTH_ID         2823.0      7.092455     3.656633      1.00      4.00
# YEAR_ID          2823.0   2003.815090     0.699670   2003.00   2003.00
# MSRP             2823.0    100.715551    40.187912     33.00     68.00
#
#                      50%      75%      max
# ORDERNUMBER      10262.0  10333.5  10425.0
# QUANTITYORDERED     35.0     43.0     97.0
# PRICEEACH           95.7    100.0    100.0
# ORDERLINENUMBER      6.0      9.0     18.0
# ...

# %%
df.describe().T.reset_index()
# Out:
#              index   count          mean          std       min       25%  \
# 0      ORDERNUMBER  2823.0  10258.725115    92.085478  10100.00  10180.00
# 1  QUANTITYORDERED  2823.0     35.092809     9.741443      6.00     27.00
# 2        PRICEEACH  2823.0     83.658544    20.174277     26.88     68.86
# 3  ORDERLINENUMBER  2823.0      6.466171     4.225841      1.00      3.00
# 4            SALES  2823.0   3553.889072  1841.865106    482.13   2203.43
# 5           QTR_ID  2823.0      2.717676     1.203878      1.00      2.00
# 6         MONTH_ID  2823.0      7.092455     3.656633      1.00      4.00
# 7          YEAR_ID  2823.0   2003.815090     0.699670   2003.00   2003.00
# 8             MSRP  2823.0    100.715551    40.187912     33.00     68.00
#
#        50%      75%      max
# 0  10262.0  10333.5  10425.0
# 1     35.0     43.0     97.0
# 2     95.7    100.0    100.0
# 3      6.0      9.0     18.0
# 4   3184.8   4508.0  14082.8
# 5      3.0      4.0      4.0
# ...

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#              index   count          mean          std       min       25%  \
# 0      ORDERNUMBER  2823.0  10258.725115    92.085478  10100.00  10180.00
# 1  QUANTITYORDERED  2823.0     35.092809     9.741443      6.00     27.00
# 2        PRICEEACH  2823.0     83.658544    20.174277     26.88     68.86
# 3  ORDERLINENUMBER  2823.0      6.466171     4.225841      1.00      3.00
# 4            SALES  2823.0   3553.889072  1841.865106    482.13   2203.43
# 5           QTR_ID  2823.0      2.717676     1.203878      1.00      2.00
# 6         MONTH_ID  2823.0      7.092455     3.656633      1.00      4.00
# 7          YEAR_ID  2823.0   2003.815090     0.699670   2003.00   2003.00
# 8             MSRP  2823.0    100.715551    40.187912     33.00     68.00
#
#        50%      75%      max      IQR
# 0  10262.0  10333.5  10425.0   153.50
# 1     35.0     43.0     97.0    16.00
# 2     95.7    100.0    100.0    31.14
# 3      6.0      9.0     18.0     6.00
# ...

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#              index   count          mean          std       min       25%  \
# 0      ORDERNUMBER  2823.0  10258.725115    92.085478  10100.00  10180.00
# 1  QUANTITYORDERED  2823.0     35.092809     9.741443      6.00     27.00
# 2        PRICEEACH  2823.0     83.658544    20.174277     26.88     68.86
# 3  ORDERLINENUMBER  2823.0      6.466171     4.225841      1.00      3.00
# 4            SALES  2823.0   3553.889072  1841.865106    482.13   2203.43
# 5           QTR_ID  2823.0      2.717676     1.203878      1.00      2.00
# 6         MONTH_ID  2823.0      7.092455     3.656633      1.00      4.00
# 7          YEAR_ID  2823.0   2003.815090     0.699670   2003.00   2003.00
# 8             MSRP  2823.0    100.715551    40.187912     33.00     68.00
#
#        50%      75%      max      IQR        IW         UW      SkEW  kurtosis
# 0  10262.0  10333.5  10425.0   153.50  9949.750  10563.750  2.484170  6.460839
# ...

# %%
Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                      0                1           2                3  \
# index      ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER
# count           2823.0           2823.0      2823.0           2823.0
# mean      10258.725115        35.092809   83.658544         6.466171
# std          92.085478         9.741443   20.174277         4.225841
# min            10100.0              6.0       26.88              1.0
# 25%            10180.0             27.0       68.86              3.0
# 50%            10262.0             35.0        95.7              6.0
# 75%            10333.5             43.0       100.0              9.0
# max            10425.0             97.0       100.0             18.0
# IQR              153.5             16.0       31.14              6.0
# IW             9949.75              3.0       22.15             -6.0
# UW            10563.75             67.0      146.71             18.0
# SkEW           2.48417         2.507184    2.263975          2.29624
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# dtype: int64

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# MSRP               0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('hp_sales.csv', encoding_errors='ignore')

# %%
sns.scatterplot(x=df['MSRP'])
# Out:
# <AxesSubplot:xlabel='MSRP'>

# %%
sns.scatterplot(df['SALES'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SALES'>

# %%
sns.countplot(df['LotFrontage'])

# %%
sns.stripplot(x=df['LotArea'], y=df['LotFrontage'], jitter=True)

# %%
plt.plot(df["SALES"], df["MSRP"])
plt.title("SALES")
plt.xlabel("SALES")
plt.ylabel("MRPS")
plt.show()

# %%
df["SALES"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["MSRP"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["SALES"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
plt.plot(df["MSRP"], df["SALES"])

# %%
df[["SALES","MSRP"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["SALES"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="MSRP", y="MSRP", data=df)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='MSRP'>

# %%
sns.violinplot(x="MSRP", y="SALES", data=df)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='SALES'>

# %%
sns.kdeplot(df["MSRP"], shade=True)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='Density'>

# %%
sns.rugplot(df["SALES"])
# Out:
# <AxesSubplot:xlabel='SALES'>

# %%
plt.scatter(df["MSRP"], df["SALES"])

# %%
plt.scatter(df["SALES"], df["MSRP"], s=df["SALES"]*100)

# %%
df["SALES"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='SALES'>

# %%
df[["SALES","MSRP"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>
