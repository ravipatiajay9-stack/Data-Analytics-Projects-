# Low         6835.0  3.664857e+01  5.280782e+01  6.562500e-02  2.036500e+00
# Close       6835.0  3.711496e+01  5.344923e+01  6.979200e-02  2.075500e+00
# Volume      6835.0  1.382271e+08  1.382910e+08  9.744000e+06  6.517200e+07
#
#                      50%           75%           max
# Unnamed: 0  3.417000e+03  5.125500e+03  6.834000e+03
# Open        8.529500e+00  5.023275e+01  2.000900e+02
# High        8.626500e+00  5.042575e+01  2.012000e+02
# Low         8.420000e+00  4.981125e+01  1.990500e+02
# Close       8.519500e+00  5.007775e+01  2.000000e+02
# Volume      1.022200e+08  1.568280e+08  2.086584e+09

# %%
df.describe().T.reset_index()
# Out:
#         index   count          mean           std           min           25%  \
# 0  Unnamed: 0  6835.0  3.417000e+03  1.973239e+03  0.000000e+00  1.708500e+03
# 1        Open  6835.0  3.712186e+01  5.346954e+01  7.031300e-02  2.069750e+00
# 2        High  6835.0  3.756040e+01  5.407779e+01  7.239600e-02  2.118500e+00
# 3         Low  6835.0  3.664857e+01  5.280782e+01  6.562500e-02  2.036500e+00
# 4       Close  6835.0  3.711496e+01  5.344923e+01  6.979200e-02  2.075500e+00
# 5      Volume  6835.0  1.382271e+08  1.382910e+08  9.744000e+06  6.517200e+07
#
#             50%           75%           max
# 0  3.417000e+03  5.125500e+03  6.834000e+03
# 1  8.529500e+00  5.023275e+01  2.000900e+02
# 2  8.626500e+00  5.042575e+01  2.012000e+02
# 3  8.420000e+00  4.981125e+01  1.990500e+02
# 4  8.519500e+00  5.007775e+01  2.000000e+02
# 5  1.022200e+08  1.568280e+08  2.086584e+09

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#         index   count          mean           std           min           25%  \
# 0  Unnamed: 0  6835.0  3.417000e+03  1.973239e+03  0.000000e+00  1.708500e+03
# 1        Open  6835.0  3.712186e+01  5.346954e+01  7.031300e-02  2.069750e+00
# 2        High  6835.0  3.756040e+01  5.407779e+01  7.239600e-02  2.118500e+00
# 3         Low  6835.0  3.664857e+01  5.280782e+01  6.562500e-02  2.036500e+00
# 4       Close  6835.0  3.711496e+01  5.344923e+01  6.979200e-02  2.075500e+00
# 5      Volume  6835.0  1.382271e+08  1.382910e+08  9.744000e+06  6.517200e+07
#
#             50%           75%           max           IQR
# 0  3.417000e+03  5.125500e+03  6.834000e+03  3.417000e+03
# 1  8.529500e+00  5.023275e+01  2.000900e+02  4.816300e+01
# 2  8.626500e+00  5.042575e+01  2.012000e+02  4.830725e+01
# 3  8.420000e+00  4.981125e+01  1.990500e+02  4.777475e+01
# 4  8.519500e+00  5.007775e+01  2.000000e+02  4.800225e+01
# 5  1.022200e+08  1.568280e+08  2.086584e+09  9.165600e+07

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#         index   count          mean           std           min           25%  \
# 0  Unnamed: 0  6835.0  3.417000e+03  1.973239e+03  0.000000e+00  1.708500e+03
# 1        Open  6835.0  3.712186e+01  5.346954e+01  7.031300e-02  2.069750e+00
# 2        High  6835.0  3.756040e+01  5.407779e+01  7.239600e-02  2.118500e+00
# 3         Low  6835.0  3.664857e+01  5.280782e+01  6.562500e-02  2.036500e+00
# 4       Close  6835.0  3.711496e+01  5.344923e+01  6.979200e-02  2.075500e+00
# 5      Volume  6835.0  1.382271e+08  1.382910e+08  9.744000e+06  6.517200e+07
#
#             50%           75%           max           IQR            IW  \
# 0  3.417000e+03  5.125500e+03  6.834000e+03  3.417000e+03 -3.417000e+03
# 1  8.529500e+00  5.023275e+01  2.000900e+02  4.816300e+01 -7.017475e+01
# 2  8.626500e+00  5.042575e+01  2.012000e+02  4.830725e+01 -7.034238e+01
# 3  8.420000e+00  4.981125e+01  1.990500e+02  4.777475e+01 -6.962562e+01
# ...

# %%
Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                        0           1            2            3            4  \
# index         Unnamed: 0        Open         High          Low        Close
# count             6835.0      6835.0       6835.0       6835.0       6835.0
# mean              3417.0   37.121857    37.560395     36.64857    37.114956
# std          1973.238877   53.469538    54.077785    52.807824    53.449231
# min                  0.0    0.070313     0.072396     0.065625     0.069792
# 25%               1708.5     2.06975       2.1185       2.0365       2.0755
# 50%               3417.0      8.5295       8.6265         8.42       8.5195
# 75%               5125.5    50.23275    50.425751    49.811249    50.077749
# max               6834.0  200.089996   201.199997   199.050003        200.0
# IQR               3417.0      48.163    48.307251    47.774749    48.002249
# IW               -3417.0   -70.17475   -70.342376   -69.625623   -69.927874
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Unnamed: 0    0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# Unnamed: 0    0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Unnamed: 0    0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# Unnamed: 0    0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(x=df['Open'])
# Out:
# <AxesSubplot:xlabel='Open'>

# %%
sns.scatterplot(df['High'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
sns.countplot(df['Open'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='count'>

# %%
sns.stripplot(x=df['Open'], y=df['Low'], jitter=True)

# %%
plt.plot(df["Low"], df["Amzone"])
plt.title("Open")
plt.xlabel("Low")
plt.ylabel("Open")
plt.show()

# %%
df["Open"].value_counts().plot(kind="bar")

# %%
df["Low"].value_counts().plot(kind="barh")

# %%
df["High"].value_counts().plot(kind="barh")

# %%
plt.plot(df["Hiogh"], df["Low"])

# %%
df[["Low","High"]].plot.area()

# %%
df["Low"].plot(kind="hist", bins=10)

# %%
sns.boxplot(x="Open", y="Low", data=df)

# %%
sns.violinplot(x="Low", y="High", data=df)

# %%
sns.kdeplot(df["Low"], shade=True)

# %%
sns.rugplot(df["High"])

# %%
plt.scatter(df["Low"], df["High"])

# %%
plt.scatter(df["Low"], df["Low"], s=df["Products"]*100)

# %%
df["Low"].value_counts().plot(kind="pie", autopct="%1.1f%%")

# %%
df[["High","Low"]].plot.area(stacked=True)
