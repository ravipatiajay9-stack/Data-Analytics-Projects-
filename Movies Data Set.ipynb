# %%
import pandas as pd

# %%
df=pd.read_csv("hp_movies.csv")

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2698

# %%
df.drop(5)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df1=df.dropna()
df1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df1.reset_index()
# Out:
#       index  color      director_name  num_critic_for_reviews  duration  \
# 0         0  Color      James Cameron                   723.0     178.0
# 1         1  Color     Gore Verbinski                   302.0     169.0
# 2         2  Color         Sam Mendes                   602.0     148.0
# 3         3  Color  Christopher Nolan                   813.0     164.0
# 4         5  Color     Andrew Stanton                   462.0     132.0
# ...     ...    ...                ...                     ...       ...
# 3751   5026  Color    Olivier Assayas                    81.0     110.0
# 3752   5027  Color       Jafar Panahi                    64.0      90.0
# 3753   5033  Color      Shane Carruth                   143.0      77.0
# 3754   5035  Color   Robert Rodriguez                    56.0      81.0
# 3755   5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# ...

# %%
df1.reset_index(drop=True)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3751  Color    Olivier Assayas                    81.0     110.0
# 3752  Color       Jafar Panahi                    64.0      90.0
# 3753  Color      Shane Carruth                   143.0      77.0
# 3754  Color   Robert Rodriguez                    56.0      81.0
# 3755  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df.fillna(5)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4         5        Doug Walker                     5.0       5.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                  5                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4993.0  1.401943e+02  1.216017e+02     1.00
# duration                   5028.0  1.072011e+02  2.519744e+01     7.00
# director_facebook_likes    4939.0  6.865092e+02  2.813329e+03     0.00
# actor_3_facebook_likes     5020.0  6.450098e+02  1.665042e+03     0.00
# actor_1_facebook_likes     5036.0  6.560047e+03  1.502076e+04     0.00
# gross                      4159.0  4.846841e+07  6.845299e+07   162.00
# num_voted_users            5043.0  8.366816e+04  1.384853e+05     5.00
# cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# facenumber_in_poster       5030.0  1.371173e+00  2.013576e+00     0.00
# num_user_for_reviews       5022.0  2.727708e+02  3.779829e+02     1.00
# budget                     4551.0  3.975262e+07  2.061149e+08   218.00
# title_year                 4935.0  2.002471e+03  1.247460e+01  1916.00
# ...

# %%
df.describe().T.reset_index()
# Out:
#                         index   count          mean           std      min  \
# 0      num_critic_for_reviews  4993.0  1.401943e+02  1.216017e+02     1.00
# 1                    duration  5028.0  1.072011e+02  2.519744e+01     7.00
# 2     director_facebook_likes  4939.0  6.865092e+02  2.813329e+03     0.00
# 3      actor_3_facebook_likes  5020.0  6.450098e+02  1.665042e+03     0.00
# 4      actor_1_facebook_likes  5036.0  6.560047e+03  1.502076e+04     0.00
# 5                       gross  4159.0  4.846841e+07  6.845299e+07   162.00
# 6             num_voted_users  5043.0  8.366816e+04  1.384853e+05     5.00
# 7   cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# 8        facenumber_in_poster  5030.0  1.371173e+00  2.013576e+00     0.00
# 9        num_user_for_reviews  5022.0  2.727708e+02  3.779829e+02     1.00
# 10                     budget  4551.0  3.975262e+07  2.061149e+08   218.00
# ...

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#                         index   count          mean           std      min  \
# 0      num_critic_for_reviews  4993.0  1.401943e+02  1.216017e+02     1.00
# 1                    duration  5028.0  1.072011e+02  2.519744e+01     7.00
# 2     director_facebook_likes  4939.0  6.865092e+02  2.813329e+03     0.00
# 3      actor_3_facebook_likes  5020.0  6.450098e+02  1.665042e+03     0.00
# 4      actor_1_facebook_likes  5036.0  6.560047e+03  1.502076e+04     0.00
# 5                       gross  4159.0  4.846841e+07  6.845299e+07   162.00
# 6             num_voted_users  5043.0  8.366816e+04  1.384853e+05     5.00
# 7   cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# 8        facenumber_in_poster  5030.0  1.371173e+00  2.013576e+00     0.00
# 9        num_user_for_reviews  5022.0  2.727708e+02  3.779829e+02     1.00
# 10                     budget  4551.0  3.975262e+07  2.061149e+08   218.00
# ...

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#                         index   count          mean           std      min  \
# 0      num_critic_for_reviews  4993.0  1.401943e+02  1.216017e+02     1.00
# 1                    duration  5028.0  1.072011e+02  2.519744e+01     7.00
# 2     director_facebook_likes  4939.0  6.865092e+02  2.813329e+03     0.00
# 3      actor_3_facebook_likes  5020.0  6.450098e+02  1.665042e+03     0.00
# 4      actor_1_facebook_likes  5036.0  6.560047e+03  1.502076e+04     0.00
# 5                       gross  4159.0  4.846841e+07  6.845299e+07   162.00
# 6             num_voted_users  5043.0  8.366816e+04  1.384853e+05     5.00
# 7   cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# 8        facenumber_in_poster  5030.0  1.371173e+00  2.013576e+00     0.00
# 9        num_user_for_reviews  5022.0  2.727708e+02  3.779829e+02     1.00
# 10                     budget  4551.0  3.975262e+07  2.061149e+08   218.00
# ...

# %%
Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                               0           1                        2   \
# index     num_critic_for_reviews    duration  director_facebook_likes
# count                     4993.0      5028.0                   4939.0
# mean                  140.194272  107.201074               686.509212
# std                   121.601675   25.197441              2813.328607
# min                          1.0         7.0                      0.0
# 25%                         50.0        93.0                      7.0
# 50%                        110.0       103.0                     49.0
# 75%                        195.0       118.0                    194.5
# max                        813.0       511.0                  23000.0
# IQR                        145.0        25.0                    187.5
# IW                        -167.5        55.5                  -274.25
# UW                         412.5       155.5                   475.75
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_1_facebook_likes         7
# gross                        884
# num_voted_users                0
# cast_total_facebook_likes      0
# facenumber_in_poster          13
# num_user_for_reviews          21
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_1_facebook_likes         7
# gross                        884
# num_voted_users                0
# cast_total_facebook_likes      0
# facenumber_in_poster          13
# num_user_for_reviews          21
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_1_facebook_likes         7
# gross                        884
# num_voted_users                0
# cast_total_facebook_likes      0
# facenumber_in_poster          13
# num_user_for_reviews          21
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_1_facebook_likes         7
# gross                        884
# num_voted_users                0
# cast_total_facebook_likes      0
# facenumber_in_poster          13
# num_user_for_reviews          21
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_1_facebook_likes         7
# gross                        884
# num_voted_users                0
# cast_total_facebook_likes      0
# facenumber_in_poster          13
# num_user_for_reviews          21
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("hp_movies.csv")

# %%
sns.scatterplot(x=df['duration'])
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
sns.scatterplot(df['gross'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross'>

# %%
sns.countplot(df['gross'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross', ylabel='count'>

# %%
sns.stripplot(x=df['gross'], y=df['duration'], jitter=True)

# %%
plt.plot(df["duration"], df["gross"])
plt.title("Houses ")
plt.xlabel("duration")
plt.ylabel("gross")
plt.show()

# %%
df["duration"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["gross"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.plot(df["gross"], df["duration"])

# %%
df[["duration","gross"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["duration"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="duration", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='gross'>

# %%
sns.violinplot(x="duration", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='gross'>

# %%
sns.kdeplot(df["gross"], shade=True)
# Out:
# <AxesSubplot:xlabel='gross', ylabel='Density'>

# %%
sns.rugplot(df["duration"])
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
plt.scatter(df["duration"], df["gross"])

# %%
df["duration"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='duration'>

# %%
df[["duration","gross"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>
