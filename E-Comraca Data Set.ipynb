# %%
import pandas as pd

# %%
df=pd.read_csv("E-comrace.csv")

# %%
df
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Order ID                   object
# Customer ID                object
# Platform                   object
# Order Date & Time          object
# Delivery Time (Minutes)     int64
# Product Category           object
# Order Value (INR)           int64
# Customer Feedback          object
# Service Rating              int64
# Delivery Delay             object
# Refund Requested           object
# dtype: object

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# ...

# %%
df.isnull().sum()
# Out:
# Order ID                   0
# Customer ID                0
# Platform                   0
# Order Date & Time          0
# Delivery Time (Minutes)    0
# Product Category           0
# Order Value (INR)          0
# Customer Feedback          0
# Service Rating             0
# Delivery Delay             0
# Refund Requested           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop(5)
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# ...

# %%
df1=df.dropna()
df1
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
df1.reset_index()
# Out:
#        index   Order ID Customer ID Platform Order Date & Time  \
# 0          0  ORD000001    CUST2824  JioMart           19:29.5
# 1          1  ORD000002    CUST1409  Blinkit           54:29.5
# 2          2  ORD000003    CUST5506  JioMart           21:29.5
# 3          3  ORD000004    CUST5012  JioMart           19:29.5
# 4          4  ORD000005    CUST4657  Blinkit           49:29.5
# ...      ...        ...         ...      ...               ...
# 99995  99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# ...

# %%
df1.reset_index(drop=True)
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
df.fillna(5)
# Out:
#         Order ID Customer ID Platform Order Date & Time  \
# 0      ORD000001    CUST2824  JioMart           19:29.5
# 1      ORD000002    CUST1409  Blinkit           54:29.5
# 2      ORD000003    CUST5506  JioMart           21:29.5
# 3      ORD000004    CUST5012  JioMart           19:29.5
# 4      ORD000005    CUST4657  Blinkit           49:29.5
# ...          ...         ...      ...               ...
# 99995  ORD099996    CUST5324  JioMart           49:29.5
# 99996  ORD099997    CUST1677  JioMart           18:29.5
# 99997  ORD099998    CUST8198  JioMart           27:29.5
# 99998  ORD099999    CUST9975  JioMart           14:29.5
# 99999  ORD100000    CUST3748  JioMart           41:29.5
#
#        Delivery Time (Minutes)     Product Category  Order Value (INR)  \
# 0                           30  Fruits & Vegetables                382
# 1                           16                Dairy                279
# 2                           25            Beverages                599
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Customer ID', 'Platform', 'Order Date & Time',
#        'Delivery Time (Minutes)', 'Product Category', 'Order Value (INR)',
#        'Customer Feedback', 'Service Rating', 'Delivery Delay',
#        'Refund Requested'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Delivery Time (Minutes)  Order Value (INR)  Service Rating
# count            100000.000000      100000.000000   100000.000000
# mean                 29.536140         590.994400        3.240790
# std                   9.958933         417.409058        1.575962
# min                   5.000000          50.000000        1.000000
# 25%                  23.000000         283.000000        2.000000
# 50%                  30.000000         481.000000        3.000000
# 75%                  36.000000         770.000000        5.000000
# max                  76.000000        2000.000000        5.000000

# %%
df.describe().T
# Out:
#                             count       mean         std   min    25%    50%  \
# Delivery Time (Minutes)  100000.0   29.53614    9.958933   5.0   23.0   30.0
# Order Value (INR)        100000.0  590.99440  417.409058  50.0  283.0  481.0
# Service Rating           100000.0    3.24079    1.575962   1.0    2.0    3.0
#
#                            75%     max
# Delivery Time (Minutes)   36.0    76.0
# Order Value (INR)        770.0  2000.0
# Service Rating             5.0     5.0

# %%
df.describe().T.reset_index()
# Out:
#                      index     count       mean         std   min    25%  \
# 0  Delivery Time (Minutes)  100000.0   29.53614    9.958933   5.0   23.0
# 1        Order Value (INR)  100000.0  590.99440  417.409058  50.0  283.0
# 2           Service Rating  100000.0    3.24079    1.575962   1.0    2.0
#
#      50%    75%     max
# 0   30.0   36.0    76.0
# 1  481.0  770.0  2000.0
# 2    3.0    5.0     5.0

# %%
Summary=df.describe().T.reset_index()

# %%
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary
# Out:
#                      index     count       mean         std   min    25%  \
# 0  Delivery Time (Minutes)  100000.0   29.53614    9.958933   5.0   23.0
# 1        Order Value (INR)  100000.0  590.99440  417.409058  50.0  283.0
# 2           Service Rating  100000.0    3.24079    1.575962   1.0    2.0
#
#      50%    75%     max    IQR
# 0   30.0   36.0    76.0   13.0
# 1  481.0  770.0  2000.0  487.0
# 2    3.0    5.0     5.0    3.0

# %%
Summary=df.describe().T.reset_index()
Summary["IQR"]=Summary["75%"]-Summary["25%"]
Summary["IW"]=Summary["25%"]-1.5*Summary["IQR"]
Summary["UW"]=Summary["75%"]+1.5*Summary["IQR"]
Summary["SkEW"]=df.select_dtypes(include="number").T.skew()
Summary["kurtosis"]=df.select_dtypes(include="number").T.kurt()
Summary
# Out:
#                      index     count       mean         std   min    25%  \
# 0  Delivery Time (Minutes)  100000.0   29.53614    9.958933   5.0   23.0
# 1        Order Value (INR)  100000.0  590.99440  417.409058  50.0  283.0
# 2           Service Rating  100000.0    3.24079    1.575962   1.0    2.0
#
#      50%    75%     max    IQR     IW      UW      SkEW  kurtosis
# 0   30.0   36.0    76.0   13.0    3.5    55.5  1.704689       NaN
# 1  481.0  770.0  2000.0  487.0 -447.5  1500.5  1.722257       NaN
# 2    3.0    5.0     5.0    3.0   -2.5     9.5  1.723045       NaN

# %%
Summary["varience"]=Summary["std"]**2
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
Summary["Range"]=Summary[max]-Summary[min]

Summary.T
# Out:
#                                 0                  1               2
# index     Delivery Time (Minutes)  Order Value (INR)  Service Rating
# count                    100000.0           100000.0        100000.0
# mean                     29.53614           590.9944         3.24079
# std                      9.958933         417.409058        1.575962
# min                           5.0               50.0             1.0
# 25%                          23.0              283.0             2.0
# 50%                          30.0              481.0             3.0
# 75%                          36.0              770.0             5.0
# max                          76.0             2000.0             5.0
# IQR                          13.0              487.0             3.0
# IW                            3.5             -447.5            -2.5
# UW                           55.5             1500.5             9.5
# SkEW                     1.704689           1.722257        1.723045
# ...

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Delivery Time (Minutes)    0
# Order Value (INR)          0
# Service Rating             0
# dtype: int64

# %%
merged = df.merge(Summary, left_index=True, right_index=True)

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Delivery Time (Minutes)    0
# Order Value (INR)          0
# Service Rating             0
# dtype: int64

# %%
null = pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_values")
null
# Out:
# Delivery Time (Minutes)    0
# Order Value (INR)          0
# Service Rating             0
# Name: null_values, dtype: int64

# %%
df.select_dtypes(include=["number"]).isnull().sum()
# Out:
# Delivery Time (Minutes)    0
# Order Value (INR)          0
# Service Rating             0
# dtype: int64

# %%
pd.Series(df.select_dtypes(include=["number"]).isnull().sum(), name="null_value")
# Out:
# Delivery Time (Minutes)    0
# Order Value (INR)          0
# Service Rating             0
# Name: null_value, dtype: int64

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
pd.merge(Summary,null,left_index=True,right_index=True)
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max, IQR, IW, UW, SkEW, kurtosis, varience, Range, null_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(x=df['Delivery Time (Minutes)'])
# Out:
# <AxesSubplot:xlabel='Delivery Time (Minutes)'>

# %%
sns.scatterplot(df['Delivery Time (Minutes)'])

# %%
sns.countplot(df['Service Rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Service Rating', ylabel='count'>

# %%
sns.stripplot(x=df['Delivery Time (Minutes)'], y=df['Service Rating'], jitter=True)
# Out:
# <AxesSubplot:xlabel='Delivery Time (Minutes)', ylabel='Service Rating'>

# %%
plt.plot(df["Delivery Time (Minutes)"], df["Service Rating"])
plt.title("E-ommerce")
plt.xlabel("Delivery Time (Minutes)")
plt.ylabel("Service Rating")
plt.show()

# %%
df["Delivery Time (Minutes)"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["Delivery Time (Minutes)"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.plot(df["Service Rating"], df["Delivery Time (Minutes)"])

# %%
df[["Delivery Time (Minutes)","Service Rating"]].plot.area()
# Out:
# <AxesSubplot:>

# %%
df["Delivery Time (Minutes)"].plot(kind="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="Delivery Time (Minutes)", y="Service Rating", data=df)
# Out:
# <AxesSubplot:xlabel='Delivery Time (Minutes)', ylabel='Service Rating'>

# %%
sns.violinplot(x="Delivery Time (Minutes)", y="Service Rating", data=df)
# Out:
# <AxesSubplot:xlabel='Delivery Time (Minutes)', ylabel='Service Rating'>

# %%
sns.kdeplot(df["Delivery Time (Minutes)"], shade=True)
# Out:
# <AxesSubplot:xlabel='Delivery Time (Minutes)', ylabel='Density'>

# %%
sns.rugplot(df["Delivery Time (Minutes)"])

# %%
plt.scatter(df["Delivery Time (Minutes)"], df["Service Rating"])

# %%
df["Delivery Time (Minutes)"].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Delivery Time (Minutes)'>

# %%
df[["Delivery Time (Minutes)","Service Rating"]].plot.area(stacked=True)
# Out:
# <AxesSubplot:>
